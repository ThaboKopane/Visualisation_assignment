# %%
import xlrd, xlwt
import xlsxwriter
import pandas as pd
import numpy as np

# %%
#sexData = pd.read_csv('sex_data.csv')

sexData = pd.read_excel('SexData1.xlsx')

#sexData = sexData.dropna()

# %%
commentsAgeOriginal = sexData[['Number_of_Comments_in_public_forum', 'Age']]
commentsAge = commentsAgeOriginal.dropna()

# %%
import seaborn as sns
#import plotly.plotly as py
#import plotly.graph_objs as go
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

#import squarify

# %%
import datetime
"""current_date = '2019-02-28'

cuDate = datetime.datetime.strptime(current_date, "%Y-%m-%d")"""
# Out:
# 'current_date = \'2019-02-28\'\n\ncuDate = datetime.datetime.strptime(current_date, "%Y-%m-%d")'

# %%
"""months_as_member = []
for data in sexData['Member_since']:
    monthEst = (cuDate - data).days/30
    months_as_member.append(monthEst)"""
# Out:
# "months_as_member = []\nfor data in sexData['Member_since']:\n    monthEst = (cuDate - data).days/30\n    months_as_member.append(monthEst)"

# %%
"""memberPd = pd.DataFrame({'member_length': months_as_member})


memberPd.to_excel('memberlength.xlsx')"""
# Out:
# "memberPd = pd.DataFrame({'member_length': months_as_member})\n\n\nmemberPd.to_excel('memberlength.xlsx')"

# %%
"""sexData = pd.concat([memberPd, sexData], axis=1)"""
# Out:
# 'sexData = pd.concat([memberPd, sexData], axis=1)'

# %%
"""dates = []
for i in range(0, len(sexData['Member_since'])):
    ori = sexData['Member_since'][i].split('-')
    newlist = [ori[2],ori[1],ori[0]]
    newdate = '/'.join(newlist)
    dates.append(newdate)
dateDF = pd.DataFrame({'Member_since': dates})"""
# Out:
# "dates = []\nfor i in range(0, len(sexData['Member_since'])):\n    ori = sexData['Member_since'][i].split('-')\n    newlist = [ori[2],ori[1],ori[0]]\n    newdate = '/'.join(newlist)\n    dates.append(newdate)\ndateDF = pd.DataFrame({'Member_since': dates})"

# %%
#dateDF.to_excel('dates.xlsx')

# %%
###polarity, gender, profile pictures

sexuality = sexData[['Gender', 'Sexual_orientation', 'Sexual_polarity', 'Profile_pictures']]

# %%
judas = sexData.dropna()

# %%
numericals_only = sexData[['Age','Number_of_Comments_in_public_forum', 'Profile_pictures',
                          'Number_of_offline_meetings_attended', 'Number_of_advertisments_posted']]

# %%
noNA = numericals_only.dropna()

# %%
f, ax = plt.subplots(figsize=(9,9))

sns.heatmap(noNA.corr(), annot=True)
plt.show()

# %%
genderplustime = sexData[['Gender', 'Member_since']]

# %%
#sns.barplot('Age', 'Sexual_orientation', data=judas)

# %%
plt.style.use('dark_background')
sns.boxenplot('Sexual_orientation', 'Number_of_Comments_in_public_forum', data=sexData)

# %%
judas
# Out:
#        User_ID  Gender   Age Location  Verification Sexual_orientation  \
# 0        10386    male  34.6        A  Non_Verified         Homosexual
# 1           14    male  32.2        J  Non_Verified       Heterosexual
# 2        16721    male  33.6        K  Non_Verified       Heterosexual
# 3        16957    male  34.0        H  Non_Verified       Heterosexual
# 4        17125    male  39.5        B  Non_Verified       Heterosexual
# 5        17220  female  47.8        A  Non_Verified       Heterosexual
# 6         1726    male  36.7        B  Non_Verified          bicurious
# 7         1750    male  51.0        L  Non_Verified       Heterosexual
# 8        18162  female  29.5        A  Non_Verified          bicurious
# 9        18820    male  28.0        J  Non_Verified       Heterosexual
# 10       19437    male  42.9        A  Non_Verified       Heterosexual
# 11       19732  female  45.4        A  Non_Verified       Heterosexual
# ...

# %%
plt.style.use('dark_background')
sns.catplot(x='Gender', y='Age', hue='Risk', kind='bar', data=judas)
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
meme = list(judas[judas['Gender'] == 'male']['Age'])
femme = list(judas[judas['Gender'] == 'female']['Age'])
names = ['male', 'female']
colors = ['blue', 'red']

# %%
plt.style.use('dark_background')
plt.hist([meme, femme], bins=20, normed=True, color=colors, label=names)
plt.legend()
# Out:
# /anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
plt.style.use('dark_background')
plt.hist([meme, femme], bins=50, stacked=True,normed=True, color=colors, label=names)
plt.legend()
# Out:
# /anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
plt.style.use('dark_background')
second = judas.copy()

for c in ['Age', 'Risk']:
    second[c] = second[c].astype('category').cat.codes
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.scatter(second['Number_of_advertisments_posted'], second['Risk'], s=second['Age'])

# %%
##hopefullyu the official plots

# %%
plt.style.use('dark_background')
sns.catplot(x='Sexual_orientation', y='Age', kind='boxen', data=judas )

# %%
plt.style.use('dark_background')
plt.hist(judas['Age'], bins=30)
# Out:
# (array([5.420e+02, 1.209e+03, 1.877e+03, 2.336e+03, 2.283e+03, 2.365e+03,
#         2.305e+03, 2.189e+03, 2.757e+03, 2.364e+03, 2.150e+03, 1.458e+03,
#         1.395e+03, 9.420e+02, 6.670e+02, 5.490e+02, 3.740e+02, 2.310e+02,
#         1.650e+02, 8.500e+01, 5.300e+01, 4.400e+01, 1.600e+01, 1.100e+01,
#         5.000e+00, 3.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 3.000e+00]),
#  array([18.1       , 20.40333333, 22.70666667, 25.01      , 27.31333333,
#         29.61666667, 31.92      , 34.22333333, 36.52666667, 38.83      ,
#         41.13333333, 43.43666667, 45.74      , 48.04333333, 50.34666667,
#         52.65      , 54.95333333, 57.25666667, 59.56      , 61.86333333,
#         64.16666667, 66.47      , 68.77333333, 71.07666667, 73.38      ,
#         75.68333333, 77.98666667, 80.29      , 82.59333333, 84.89666667,
#         87.2       ]),
#  <a list of 30 Patch objects>)

# %%
plt.style.use('dark_background')
plt.figure(figsize=(9,8))
sns.distplot(judas['Age'], color='red', bins=25, hist_kws={'alpha': 0.4})
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
julian = judas[judas['Risk'] != 'No_risk']

# %%
##common polarityt
plt.style.use('dark_background')
sns.catplot(x='Age', y='Sexual_polarity', hue='Gender', kind='swarm', data=judas)

# %%
##who is at risk
plt.style.use('dark_background')
sns.catplot(x='Sexual_orientation', y='Age', hue='Risk', kind='swarm', data=julian)
