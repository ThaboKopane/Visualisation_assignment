# %%
import xlrd, xlwt
import xlsxwriter
import pandas as pd
import numpy as np

# %%
#sexData = pd.read_csv('sex_data.csv')

sexData = pd.read_excel('SexData1.xlsx')

#sexData = sexData.dropna()

# %%
commentsAgeOriginal = sexData[['Number_of_Comments_in_public_forum', 'Age']]
commentsAge = commentsAgeOriginal.dropna()

# %%
import seaborn as sns
#import plotly.plotly as py
#import plotly.graph_objs as go
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

#import squarify

# %%
import pyflux

# %%
judas = sexData.dropna()

# %%
numericals_only = sexData[['Age','Number_of_Comments_in_public_forum', 'Profile_pictures',
                          'Number_of_offline_meetings_attended', 'Number_of_advertisments_posted']]

# %%
noNA = numericals_only.dropna()

# %%
plt.style.use('dark_background')
f, ax = plt.subplots(figsize=(9,9))

sns.heatmap(noNA.corr(), annot=True)
plt.show()

# %%
sns.set(font_scale=1)
plt.style.use('dark_background')
frankPlot = sns.catplot(x='Looking_for', y='Age', kind='boxen', data=judas )

# %%
julian = judas[judas['Risk'] != 'No_risk']

# %%
##common polarityt
plt.style.use('dark_background')
sns.catplot(x='Age', y='Sexual_polarity', hue='Gender', kind='swarm', data=julian)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-eb092873b7d1> in <module>
#       1 ##common polarityt
#       2 plt.style.use('dark_background')
# ----> 3 sns.catplot(x='Age', y='Sexual_polarity', hue='Gender', kind='swarm', data=julian)
#
# /anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3753
#    3754     # Draw the plot onto the facets
# -> 3755     g.map_dataframe(plot_func, x, y, hue, **plot_kws)
#    3756
#    3757     # Special case axis labels for a count type plot
#
# /anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     818
# ...

# %%
flatui = ["#9b59b6", "#ffff00", "#ff0000", "#2ecc71"]
sns.palplot(sns.color_palette(flatui))

# %%
#plt.setp(ax.get_legend().get_texts(), fontsize='22')
sns.set(font_scale=2)
plt.style.use('dark_background')
plt.figure(figsize=(20,13))
#fig, ax = plt.subplots()

swarm = sns.swarmplot(x='Sexual_orientation', y='Age', hue='Risk', hue_order=['Some_risk','Moderate_risk', 'High_risk'],
                      palette= flatui,size = 10, data=julian)

plt.show()

# %%
#swarm.fig.set_size_inches(20,13)
fig = swarm.get_figure()
fig.savefig('swarm_boxPlotbig_member_length.png')

# %%
new_pal = ["#49ADEA", "#F19FCA"]
sns.palplot(new_pal)

# %%
plt.figure(figsize=(20,13))


boxViolin = sns.violinplot(x='Sexual_orientation', y='Age', hue='Gender', data=judas, palette=new_pal)
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
fig = boxViolin.get_figure()
fig.savefig('box_violin.png')

# %%
plt.figure(figsize=(20,13))
plt.style.use('dark_background')

box_hues = sns.violinplot(x='Sexual_orientation', y='Age', hue='Gender', data=judas, palette=new_pal, size=7,
                         split=True)
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
fig = box_hues.get_figure()
fig.savefig('box_hues_pink.png')

# %%
newJohn = judas.groupby(['Risk','Gender', 'Looking_for']).size().to_frame('count').reset_index()

# %%
newJon = newJohn[newJohn['Risk'] != 'No_risk']
newJon = newJon[newJon['Looking_for'] != 'Nobody']

# %%
judas_fem = judas[judas['Gender'] != 'female']

# %%
sns.set(font_scale=2)
plt.style.use('dark_background')
plt.figure(figsize=(23,13))
g = sns.catplot(x='Risk', y='Age', hue="Looking_for",
                col="Verification", data=judas,height=10,aspect=.8)

# %%
#fig = g.get_figure()
g.savefig('gender_last_loginV.png')

# %%
sns.set(font_scale=1.5)
plt.style.use('dark_background')
plt.figure(figsize=(23,13))

hello = sns.catplot(x="Sexual_orientation", y="count", col="Gender",
            data=john, saturation=.5,
            kind="bar", ci=None, aspect=1.3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-c7be436f2d89> in <module>
#       4
#       5 hello = sns.catplot(x="Sexual_orientation", y="count", col="Gender",
# ----> 6             data=john, saturation=.5,
#       7             kind="bar", ci=None, aspect=1.3)
#
# NameError: name 'john' is not defined
